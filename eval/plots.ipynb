# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

#setup
file_build_up = "../experiments/build_up.csv"
file_build_up_leaf = "../experiments/build_up_leaf.csv"

# %%
#read files
df1 = pd.read_csv(file_build_up, delim_whitespace=True)  
#df2 = pd.read_csv(file_build_up_leaf)  
#df1.head(n=10)

# %%
#define index column
df1.set_index('n', inplace=True)

#group data by x and display y as line chart
df1.groupby('algo')['insert'].plot(legend=True)
# Out:
# algo
# bp    AxesSubplot(0.125,0.125;0.775x0.755)
# bv    AxesSubplot(0.125,0.125;0.775x0.755)
# Name: insert, dtype: object

# %%
#compute avg and std

test1 = df1.groupby(by=['algo', 'n']).mean().plot(x='n', y='insert')
test2 = df1.groupby(by=['algo', 'n']).std()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/.local/lib/python3.8/site-packages/pandas/core/indexes/base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File ~/.local/lib/python3.8/site-packages/pandas/_libs/index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/.local/lib/python3.8/site-packages/pandas/_libs/index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'n'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
ax = plt.gca()

#df.plot(kind='line',x='name',y='num_children',ax=ax)
# test1.head()
test1.plot(kind='line',x='n',y='insert')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/.local/lib/python3.8/site-packages/pandas/core/indexes/base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File ~/.local/lib/python3.8/site-packages/pandas/_libs/index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/.local/lib/python3.8/site-packages/pandas/_libs/index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'n'
#
# The above exception was the direct cause of the following exception:
#
# ...
